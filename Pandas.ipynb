# %%
import pandas as pd
import csv
df = pd.read_csv('dataset/year2017.csv')

df.head(19)
df.drop(0)
df['let_col'] = 1
df.head()
del df['Unnamed: 16']
del df['Unnamed: 17']
del df['Unnamed: 18']
del df['Unnamed: 19']
df.head()
# Out:
#    Year   Month   Day                            Country  \
# 0  2017       1     2                        Afghanistan
# 1  2017       1     3                              Sudan
# 2  2017       1     1   Democratic Republic of the Congo
# 3  2017       1     1   Democratic Republic of the Congo
# 4  2017       1     1                             Turkey
#
#                         Region         city   latitude  longitude  \
# 0                   South Asia   Takhta Pul  31.320556  65.961111
# 1           Sub-Saharan Africa      Fantaga  12.921007  24.318324
# 2           Sub-Saharan Africa       Saboko   1.452372  29.875162
# 3           Sub-Saharan Africa       Bialee    1.45237  29.875186
# 4   Middle East & North Africa     Istanbul  41.106178  28.689863
#
#                      AttackType  Killed  Wounded                      Target  \
# 0   Hostage Taking (Kidnapping)       0        0        Construction Workers
# ...
