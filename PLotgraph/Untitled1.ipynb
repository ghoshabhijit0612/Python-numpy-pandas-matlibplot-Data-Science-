# %%
import matplotlib.pyplot as plt
import numpy as np

import csv
x = np.arange(0 ,40 ,2)
y =2**x
plt.plot(x,y)
plt.grid()
plt.show()

# %%
laptops =['hp','dell','levovo','asus','apple','microsoft']
lebels =['hp','dell','levovo','asus','apple','microsoft']
explode =[0,0,0,0,0.1,0]
sold = [23222,45321,34234,69999,12888,10000]
plt.pie(sold,labels= laptops,explode= explode)
plt.show()

# %%
x = [1,2,1,2,1,3,4,5,5]
plt.hist(x)
plt.show()

# %%
import pandas as pd
data = pd.read_csv('/dataset/amazon_jobs.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('./dataset/amazon_jobs.csv')
#       3 data
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
